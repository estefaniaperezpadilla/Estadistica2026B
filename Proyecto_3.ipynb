# %% [markdown]
# <a href="https://colab.research.google.com/github/estefaniaperezpadilla/Estadistica2026B/blob/main/Proyecto_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
link = "https://raw.githubusercontent.com/estefaniaperezpadilla/Estadistica2026B/refs/heads/main/Student%20Performance/StudentPerformanceFactors.csv"

import pandas as pd

df = pd.read_csv(link)

df
# Out:
#       Horas__de_estudio  Asistencia Participacion_padres Acceso_a_recursos  \
# 0                    23          84                  Low              High
# 1                    19          64                  Low            Medium
# 2                    24          98               Medium            Medium
# 3                    29          89                  Low            Medium
# 4                    19          92               Medium            Medium
# ...                 ...         ...                  ...               ...
# 6602                 25          69                 High            Medium
# 6603                 23          76                 High            Medium
# 6604                 20          90               Medium               Low
# 6605                 10          86                 High              High
# 6606                 15          67               Medium               Low
#
# ...

# %%
df.columns
# Out:
# Index(['Horas__de_estudio', 'Asistencia', 'Participacion_padres',
#        'Acceso_a_recursos', 'Actividades_extracurriculares', 'Horas_de_sueño',
#        'Puntuaciones_anteriores', 'Nivel_motivacion', 'Acceso_internet',
#        'Sesiones_de_tutoria', 'Ingresos_familiares', 'Calidad_del_profesor',
#        'Tipo_de_escuela', 'Influencia_de_los_compañeros', 'Actividad_fisica',
#        'Dificultades_aprendisaje', 'Nivel_educativo_padres',
#        'Distacia_del_hogar', 'Genero', 'Puntuacion_examen'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Horas__de_estudio              6607 non-null   int64
#  1   Asistencia                     6607 non-null   int64
#  2   Participacion_padres           6607 non-null   object
#  3   Acceso_a_recursos              6607 non-null   object
#  4   Actividades_extracurriculares  6607 non-null   object
#  5   Horas_de_sueño                 6607 non-null   int64
#  6   Puntuaciones_anteriores        6607 non-null   int64
#  7   Nivel_motivacion               6607 non-null   object
#  8   Acceso_internet                6607 non-null   object
#  9   Sesiones_de_tutoria            6607 non-null   int64
#  10  Ingresos_familiares            6607 non-null   object
#  11  Calidad_del_profesor           6529 non-null   object
# ...

# %%
df.dropna(inplace = True)
df
# Out:
#       Horas__de_estudio  Asistencia Participacion_padres Acceso_a_recursos  \
# 0                    23          84                  Low              High
# 1                    19          64                  Low            Medium
# 2                    24          98               Medium            Medium
# 3                    29          89                  Low            Medium
# 4                    19          92               Medium            Medium
# ...                 ...         ...                  ...               ...
# 6602                 25          69                 High            Medium
# 6603                 23          76                 High            Medium
# 6604                 20          90               Medium               Low
# 6605                 10          86                 High              High
# 6606                 15          67               Medium               Low
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6378 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Horas__de_estudio              6378 non-null   int64
#  1   Asistencia                     6378 non-null   int64
#  2   Participacion_padres           6378 non-null   object
#  3   Acceso_a_recursos              6378 non-null   object
#  4   Actividades_extracurriculares  6378 non-null   object
#  5   Horas_de_sueño                 6378 non-null   int64
#  6   Puntuaciones_anteriores        6378 non-null   int64
#  7   Nivel_motivacion               6378 non-null   object
#  8   Acceso_internet                6378 non-null   object
#  9   Sesiones_de_tutoria            6378 non-null   int64
#  10  Ingresos_familiares            6378 non-null   object
#  11  Calidad_del_profesor           6378 non-null   object
# ...

# %%
# eliminar columnas duplicadas (se queda con la primera)
df = df.loc[:, ~df.columns.duplicated()]

# %%
# convertir a numérico
df['Puntuacion_examen'] = pd.to_numeric(df['Puntuacion_examen'], errors='coerce')

# eliminar nulos
df = df.dropna(subset=['Puntuacion_examen', 'Acceso_a_recursos'])

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
# The column 'Participacion_padres' was renamed to 'Acceso_a_recursos' in a previous step.
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Participacion_padres'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   High    Low  -1.7334   0.0 -2.0626 -1.4042   True
#   High Medium   -0.999   0.0 -1.2636 -0.7344   True
#    Low Medium   0.7344   0.0  0.4363  1.0326   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Participacion_padres"]=df["Participacion_padres"].map({"Low":0,"Medium":1,"High":2})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres Acceso_a_recursos  \
# 0                    23          84                     0              High
# 1                    19          64                     0            Medium
# 2                    24          98                     1            Medium
# 3                    29          89                     0            Medium
# 4                    19          92                     1            Medium
# ...                 ...         ...                   ...               ...
# 6602                 25          69                     2            Medium
# 6603                 23          76                     2            Medium
# 6604                 20          90                     1               Low
# 6605                 10          86                     2              High
# 6606                 15          67                     1               Low
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
# The column 'Participacion_padres' was renamed to 'Acceso_a_recursos' in a previous step.
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Acceso_a_recursos'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#   High    Low  -1.8795   0.0 -2.2071 -1.5518   True
#   High Medium  -0.9468   0.0 -1.2088 -0.6848   True
#    Low Medium   0.9327   0.0   0.633  1.2323   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Acceso_a_recursos"]=df["Acceso_a_recursos"].map({"Low":0,"Medium":1,"High":2})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
# The column 'Participacion_padres' was renamed to 'Acceso_a_recursos' in a previous step.
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Actividades_extracurriculares'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     No    Yes   0.5032   0.0 0.3077 0.6987   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Actividades_extracurriculares"]=df["Actividades_extracurriculares"].map({"No":0,"Yes":1})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
# The column 'Participacion_padres' was renamed to 'Acceso_a_recursos' in a previous step.
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Nivel_motivacion'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low  -0.9794    0.0 -1.3115 -0.6474   True
#   High Medium   -0.405 0.0048 -0.7071  -0.103   True
#    Low Medium   0.5744    0.0  0.3086  0.8402   True
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Nivel_motivacion"]=df["Nivel_motivacion"].map({"Low":0,"Medium":1,"High":2})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
# The column 'Participacion_padres' was renamed to 'Acceso_a_recursos' in a previous step.
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Ingresos_familiares'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low  -0.9882    0.0 -1.3048 -0.6717   True
#   High Medium  -0.4705 0.0015 -0.7873 -0.1536   True
#    Low Medium   0.5178    0.0  0.2631  0.7725   True
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Ingresos_familiares"]=df["Ingresos_familiares"].map({"Low":0,"Medium":1,"High":2})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Acceso_internet'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj lower  upper  reject
# -------------------------------------------------
#     No    Yes   0.7549   0.0 0.3929 1.1169   True
# -------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Acceso_internet"]=df["Acceso_internet"].map({"No":0,"Yes":1})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Calidad_del_profesor'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#   High    Low   -0.906    0.0 -1.3224 -0.4896   True
#   High Medium  -0.5632    0.0 -0.8198 -0.3066   True
#    Low Medium   0.3428 0.0971 -0.0462  0.7318  False
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Calidad_del_profesor"]=df["Calidad_del_profesor"].map({"Low":0,"Medium":1,"High":2})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Tipo_de_escuela'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1 group2 meandiff p-adj   lower  upper  reject
# ----------------------------------------------------
# Private Public  -0.0924 0.3855 -0.3011 0.1163  False
# ----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Tipo_de_escuela"]=df["Tipo_de_escuela"].map({"Private":0,"Public":1})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Influencia_de_los_compañeros'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1   group2  meandiff p-adj  lower  upper  reject
# ------------------------------------------------------
# Negative  Neutral   0.6329    0.0 0.3229 0.9429   True
# Negative Positive   1.0538    0.0  0.745 1.3626   True
#  Neutral Positive   0.4209 0.0004 0.1638 0.6779   True
# ------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Influencia_de_los_compañeros"]=df["Influencia_de_los_compañeros"].map({"Negative":0,"Neutral":1,"Positive":2})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Dificultades_aprendisaje'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#     No    Yes  -1.0725   0.0 -1.3852 -0.7598   True
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Dificultades_aprendisaje"]=df["Dificultades_aprendisaje"].map({"No":0,"Yes":1})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Nivel_educativo_padres'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#       Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#    group1      group2    meandiff p-adj   lower   upper  reject
# ---------------------------------------------------------------
#     College  High School  -0.4635 0.0001 -0.7268 -0.2002   True
#     College Postgraduate   0.6142    0.0  0.2856  0.9429   True
# High School Postgraduate   1.0778    0.0  0.7754  1.3801   True
# ---------------------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Nivel_educativo_padres"]=df["Nivel_educativo_padres"].map({"Postgraduate":0,"High School":1,"College":2})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Distacia_del_hogar'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
#  Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
#  group1   group2  meandiff p-adj lower  upper  reject
# -----------------------------------------------------
#      Far Moderate   0.4882 0.017 0.0705 0.9059   True
#      Far     Near   1.0154   0.0 0.6237  1.407   True
# Moderate     Near   0.5272   0.0 0.2722 0.7822   True
# -----------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Distacia_del_hogar"]=df["Distacia_del_hogar"].map({"Near":0,"Moderate":1,"Far":2})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#test de tukey
from statsmodels.stats.multicomp import pairwise_tukeyhsd
import matplotlib.pyplot as plt

nivel_de_significancia = 0.05

# Prueba de Tukey
tukey = pairwise_tukeyhsd(endog=df['Puntuacion_examen'], groups=df['Genero'], alpha=nivel_de_significancia)

# Mostrar los resultados
print(tukey)

# Gráfico de las diferencias entre grupos
tukey.plot_simultaneous(ylabel="Grupos", xlabel="Medias")

plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior
plt.title("Múltiples comparaciones entre todos los pares (Tukey)")
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
# Female   Male  -0.0391 0.6937 -0.2337 0.1555  False
# ---------------------------------------------------
# Text(0.5, 1.0, 'Múltiples comparaciones entre todos los pares (Tukey)')

# %%
df["Genero"]=df["Genero"].map({"Male":0,"Female":1})

df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#Mapa de calor

import seaborn as sns
import matplotlib.pyplot as plt

correlation_matrix = df.corr()
plt.figure(figsize=(30, 18))
sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            fmt=".4f",
            square=True,
            center=0,
            cbar_kws={"shrink": .8})
plt.title('Mapa de Calor de la Matriz de Correlación')
plt.show()

# %%
df=df[["Horas__de_estudio", "Asistencia", "Participacion_padres", "Acceso_a_recursos", "Actividades_extracurriculares", "Horas_de_sueño", "Puntuaciones_anteriores", "Nivel_motivacion", "Acceso_internet", "Sesiones_de_tutoria", "Ingresos_familiares", "Calidad_del_profesor","Tipo_de_escuela", "Influencia_de_los_compañeros", "Actividad_fisica", "Dificultades_aprendisaje", "Nivel_educativo_padres", "Distacia_del_hogar", "Genero", "Puntuacion_examen"]]
df
# Out:
#       Horas__de_estudio  Asistencia  Participacion_padres  Acceso_a_recursos  \
# 0                    23          84                     0                  2
# 1                    19          64                     0                  1
# 2                    24          98                     1                  1
# 3                    29          89                     0                  1
# 4                    19          92                     1                  1
# ...                 ...         ...                   ...                ...
# 6602                 25          69                     2                  1
# 6603                 23          76                     2                  1
# 6604                 20          90                     1                  0
# 6605                 10          86                     2                  2
# 6606                 15          67                     1                  0
#
# ...

# %%
#Realice unatablaANOVAeinterpreteelresultado.
# testdeANOVA(AnalysisofVariance)
# H0:beta_1=0(Nohaycorrelación)
# H1:beta_1￿0(Síhaycorrelación)
from statsmodels.formula.api import ols
# Y~X
modelo_lineal = ols("""Puntuacion_examen ~Horas__de_estudio+Asistencia+
       Acceso_a_recursos+Actividades_extracurriculares+Horas_de_sueño+
       Puntuaciones_anteriores+Nivel_motivacion+Acceso_internet+
       Sesiones_de_tutoria+Ingresos_familiares+Calidad_del_profesor+
       Tipo_de_escuela+Influencia_de_los_compañeros+Actividad_fisica+
       Dificultades_aprendisaje+Nivel_educativo_padres+
       Distacia_del_hogar+Genero""", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova.round(4)
# Out:
#                                    df      sum_sq     mean_sq          F  \
# Horas__de_estudio                 1.0  19356.6133  19356.6133  3959.2928
# Asistencia                        1.0  33149.9475  33149.9475  6780.6463
# Acceso_a_recursos                 1.0   3051.9066   3051.9066   624.2513
# Actividades_extracurriculares     1.0    478.8880    478.8880    97.9540
# Horas_de_sueño                    1.0      8.6394      8.6394     1.7671
# Puntuaciones_anteriores           1.0   2830.6448   2830.6448   578.9934
# Nivel_motivacion                  1.0    820.3115    820.3115   167.7904
# Acceso_internet                   1.0    357.8424    357.8424    73.1948
# Sesiones_de_tutoria               1.0   2454.6230   2454.6230   502.0801
# Ingresos_familiares               1.0   1048.9418   1048.9418   214.5555
# Calidad_del_profesor              1.0    660.9680    660.9680   135.1975
# Tipo_de_escuela                   1.0      0.0065      0.0065     0.0013
# ...

# %%
x=df[["Horas__de_estudio","Asistencia",
       "Acceso_a_recursos","Actividades_extracurriculares","Horas_de_sueño",
       "Puntuaciones_anteriores","Nivel_motivacion","Acceso_internet",
       "Sesiones_de_tutoria","Ingresos_familiares","Calidad_del_profesor",
       "Tipo_de_escuela","Influencia_de_los_compañeros","Actividad_fisica",
       "Dificultades_aprendisaje","Nivel_educativo_padres",
       "Distacia_del_hogar","Genero"]]
y=df["Puntuacion_examen"]

# %%
# @title
# 2. Realice un diagrama de dispersión para estos datos.
import matplotlib.pyplot as plt

# --- Configuración general del gráfico ---
plt.figure(
    figsize=(6, 4),   # tamaño de la figura (ancho, alto) en pulgadas
    dpi=120           # resolución del gráfico
)

# --- Gráfico de dispersión ---
plt.scatter(
    y,y_calculada,
    marker="o",       # forma
    color='blue',     # color de los puntos
    edgecolor='black',    # borde de los puntos
    alpha=0.4,            # transparencia
    s=50,                 # tamaño de los puntos
    label='Puntuacion_examen' # etiqueta para la leyenda
)

# --- Gráfico de línea ---
plt.plot(
    y_calculada,y_calculada,
    color='black',   # color de la línea
    linewidth=1,        # grosor de la línea
    linestyle='--',        # estilo de línea
    marker='o',           # marcador en cada punto
    markersize=0,         # tamaño del marcador
    markerfacecolor='white',
    markeredgecolor='black',
    label='Recta de regresión'
)

# --- Título ---
plt.title(
    '''Gráfico de dispersión''',
    fontsize=14,
    fontweight='bold'
)

# --- Etiquetas de los ejes ---
plt.xlabel(
    'calificaciones_reales',
    fontsize=12
)

plt.ylabel(
    'Puntuacion_examen',
    fontsize=12
)

# --- Fuente de los ticks ---
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

# --- Márgenes ---
plt.margins(x=0.05, y=0.05)  # espacio extra alrededor de los datos
plt.gca().spines['right'].set_visible(False) # derecha
plt.gca().spines['top'].set_visible(False)   # superior

# Para eliminar márgenes completamente, usar:
# plt.margins(0)

# --- Cuadrícula (opcional, pero didáctica) ---
plt.grid(
    visible=True,
    linestyle='--',
    linewidth=0.7,
    alpha=0.1,
    color="gray"
)

# --- Leyenda ---
plt.legend(
    fontsize=10,
    loc='best',
    frameon=True
)

# --- Nota al pie ---
plt.text(
    0.4, -0.2,
    'Fuente: datos simulados para fines académicos.',
    fontsize=8,
    ha='left',
    va='center',
    transform=plt.gca().transAxes
)

# --- Guardar gráfico ---
plt.savefig(
    "grafico de dispersión",
    bbox_inches='tight'
    )

plt.show()

# %%
#Obtenga la recta de regresión ajustada y grafíquelo sobre el
# gráfico de dispersión

import statsmodels.api as sm
x_constante = sm.add_constant(x)
modelo = sm.OLS(y, x_constante).fit()
y_calculada = modelo.predict(x_constante)

modelo.params
# Out:
# const                            35.434381
# Horas__de_estudio                 0.294123
# Asistencia                        0.199572
# Participacion_padres              0.993871
# Acceso_a_recursos                 1.027529
# Actividades_extracurriculares     0.564451
# Horas_de_sueño                    0.000958
# Puntuaciones_anteriores           0.048519
# Nivel_motivacion                  0.529700
# Acceso_internet                   0.908074
# Sesiones_de_tutoria               0.499941
# Ingresos_familiares               0.534343
# Calidad_del_profesor              0.535723
# Tipo_de_escuela                   0.024930
# Influencia_de_los_compañeros      0.512073
# Actividad_fisica                  0.175427
# Dificultades_aprendisaje         -0.868644
# Nivel_educativo_padres           -0.174400
# Distacia_del_hogar               -0.469980
# Genero                            0.047767
# dtype: float64

# %%
#Calcule el coeficiente de determinación e interprete el resultado.
from sklearn.metrics import r2_score  # recomendada
r2 = r2_score(y, y_calculada)
print(f'Coeficiente de determinación: {r2: 0.2%}\n')
# Out:
# Coeficiente de determinación:  71.28%

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns
residuales= modelo.resid
# Prueba de Shapiro-Wilk
stat, valor_p_sh = shapiro(residuales)
print(f"valor-p (Shapiro) = {valor_p_sh}")

# Visualización: Q-Q plot
sm.qqplot(residuales, line='s')
plt.title("Q-Q plot de residuos")
plt.show()

# Histograma
sns.histplot(residuales, kde=True)
plt.title("Histograma de residuos")
plt.show()
# Out:
# valor-p (Shapiro) = 1.5433280252575031e-96
# /usr/local/lib/python3.12/dist-packages/scipy/stats/_axis_nan_policy.py:579: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 6378.
#   res = hypotest_fun_out(*samples, **kwds)

# %%
#Realice la prueba de Breusch-Pagan para los residuales
# y comente el resultado.

# Test de Breusch-Pagan
# H0: No hay heterocedasticidad (dispersión es igual en toda la recta)
# H1: Hay Heterocedasticidad (dispersión distinta a lo largo de la recta)
# alpha = 0.05

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp: 0.4f}\n')
# Out:
# valor_p de Breusch-Pagan:  0.7827

# %%
#Realice una tabla ANOVA e interprete el resultado.

# test de ANOVA (Analysis of Variance)
# H0: beta_1 = 0   (No hay correlación)
# H1: beta_1 ≠ 0   (Sí hay correlación)

from statsmodels.formula.api import ols
# Y ~ X
modelo_lineal = ols("Puntuacion_examen ~ Horas__de_estudio+Asistencia+Participacion_padres+Acceso_a_recursos+Actividades_extracurriculares+Horas_de_sueño+Puntuaciones_anteriores+Nivel_motivacion+Acceso_internet+Sesiones_de_tutoria+Ingresos_familiares+Calidad_del_profesor+Tipo_de_escuela+Influencia_de_los_compañeros+Actividad_fisica+Dificultades_aprendisaje+Nivel_educativo_padres+Distacia_del_hogar+Genero", data=df).fit()
tabla_anova = sm.stats.anova_lm(modelo_lineal)
tabla_anova.round(4)
# Out:
#                                    df      sum_sq     mean_sq          F  \
# Horas__de_estudio                 1.0  19356.6133  19356.6133  4386.1310
# Asistencia                        1.0  33149.9475  33149.9475  7511.6453
# Participacion_padres              1.0   2743.0824   2743.0824   621.5715
# Acceso_a_recursos                 1.0   3227.1412   3227.1412   731.2573
# Actividades_extracurriculares     1.0    535.5859    535.5859   121.3616
# Horas_de_sueño                    1.0      7.1758      7.1758     1.6260
# Puntuaciones_anteriores           1.0   2950.5365   2950.5365   668.5797
# Nivel_motivacion                  1.0    895.0450    895.0450   202.8136
# Acceso_internet                   1.0    327.0653    327.0653    74.1117
# Sesiones_de_tutoria               1.0   2474.0506   2474.0506   560.6100
# Ingresos_familiares               1.0   1013.1686   1013.1686   229.5800
# Calidad_del_profesor              1.0    621.2230    621.2230   140.7666
# ...
